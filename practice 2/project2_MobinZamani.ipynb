# %%
student_1 = {
        "first_name": "Mobin",
        "last_name": "zamani",
        "student_code": "4042000000",
        "date_of_birth": 2007,
        "desired_movie": "spiderman",
        "major": "Electrical Engineering",
        "academic_level": "B.S.",
        "gpa": 17.8,
        "favorite_courses": ["English learning"],
        "hobbies": ["Reading", "sport"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}

main_students = {
        "first_name": "Ali",
        "last_name": "Rezaei",
        "student_code": "S12345",
        "date_of_birth": 1998,
        "age": 25,
        "desired_movie": "Inception",
        "desired_song": "Queen",
        "major": "Computer Engineering",
        "academic_level": "Msater",
        "entry_year": 2018,
        "gpa": 17.5,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "career_goal": "Software Developer",
        "strengths": ["Teamwork", "Problem-solving"],
        "weaknesses": ["Public speaking"],
        "favorite_book": "The Alchemist",
        "skills": ["Python", "C++"],
        "languages": ["English", "French"],
        "volunteer_experience": ["Teaching assistant"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}
# جایگزینی تک تک موارد 
# main_students["first_name"] = "Mobin"
# main_students["last_name"] = "zamani"
# main_students["student_code"] = "4042000000"
# main_students["date_of_birth"] = 2007
# main_students["desired_movie"] = "spiderman"
# main_students["major"] = "Electrical Engineering"
# main_students["academic_level"] = "B.S."
# main_students["gpa"] = 17.8
# main_students["favorite_courses"] = "English learning"
# main_students["hobbies"] =  ["Reading", "sport"]
# main_students["feedback"] = {
#             "courses": "Challenging but rewarding",
#             "professors": "Supportive and knowledgeable"
#         }

# استفاده از متد 
main_students.update(student_1)

print(main_students)
# Out:
# {'first_name': 'Mobin', 'last_name': 'zamani', 'student_code': '4042000000', 'date_of_birth': 2007, 'age': 25, 'desired_movie': 'spiderman', 'desired_song': 'Queen', 'major': 'Electrical Engineering', 'academic_level': 'B.S.', 'entry_year': 2018, 'gpa': 17.8, 'favorite_courses': ['English learning'], 'hobbies': ['Reading', 'sport'], 'career_goal': 'Software Developer', 'strengths': ['Teamwork', 'Problem-solving'], 'weaknesses': ['Public speaking'], 'favorite_book': 'The Alchemist', 'skills': ['Python', 'C++'], 'languages': ['English', 'French'], 'volunteer_experience': ['Teaching assistant'], 'feedback': {'courses': 'Challenging but rewarding', 'professors': 'Supportive and knowledgeable'}}
